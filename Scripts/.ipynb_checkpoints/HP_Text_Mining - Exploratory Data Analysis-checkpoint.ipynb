# %% [markdown]
# ### Import Data

# %%
import pandas as pd #Importing Pandas package

Bookfile=[] #Empty "Book" list - Prepare for loop

# Loops through importing 7 HP text files - Book 1 creates table, Books 2-7 append to Book 1 table
for i in range(1,8): 
    Bookfile.append('HPBook'+str(i)+'.txt')
    FileLoc = "C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Book Text/{}".format(Bookfile[i-1])
    if i == 1:
        df = pd.read_csv(FileLoc, sep="@")
    else:
        df2 = pd.read_csv(FileLoc, sep="@")
        df = pd.concat([df, df2])

# %% [markdown]
# ### Import NLTK and Its Text Analysis Components

# %%
import nltk #Import NLTK library
nltk.download('punkt') #installed punkt to fix error
from nltk import word_tokenize
from nltk.corpus import stopwords #Import stopwords to Python

stopwords = set(stopwords.words('english')) #English stopwords assigned to "stopwords" object

import string #Punctuation

# Function for removing punctuation
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

stopwords = [''.join(item for item in x if item not in string.punctuation) for x in stopwords] #Remove punctuation from stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cluel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Creating Analysis Fields - Word Count and Word Clouds
#
# In order to do an appropriate analysis, punctuation is removed and case is lowered.
#
# For the word cloud analysis specifically, stop words are removed ("The", "And", "So", etc.)

# %%
df['WordCountText']=df['Text'].str.lower().apply(remove_punctuations).apply(word_tokenize) # Word Count Text
# Word Count
df['WordCloudText']=df['WordCountText'].apply(lambda x: [word for word in x if word not in stopwords]) # Word Cloud Text
df['WordCount'] = df['WordCountText'].str.len() #Word Count Per Chapter

df.reset_index()
# Out:
#      index                                               Text  Chapter  Book  \
# 0        0  THE BOY WHO LIVED  Mr. and Mrs. Dursley, of nu...        1     1
# 1        1  THE VANISHING GLASS  Nearly ten years had pass...        2     1
# 2        2  THE LETTERS FROM NO ONE  The escape of the Bra...        3     1
# 3        3  THE KEEPER OF THE KEYS  BOOM. They knocked aga...        4     1
# 4        4  DIAGON ALLEY  Harry woke early the next mornin...        5     1
# 5        5  THE JOURNEY FROM PLATFORM NINE AND THREE-QUART...        6     1
# 6        6  THE SORTING HAT  The door swung open at once. ...        7     1
# 7        7  THE POTIONS MASTER  There, look.\  \"Where?\" ...        8     1
# 8        8  THE MIDNIGHT DUEL  Harry had never believed he...        9     1
# 9        9  HALLOWEEN  Malfoy couldn't believe his eyes wh...       10     1
# 10      10  QUIDDITCH  As they entered November, the weath...       11     1
# 11      11  THE MIRROR OF ERISED  Christmas was coming. On...       12     1
# 12      12  NICOLAS FLAMEL  Dumbledore had convinced Harry...       13     1
# 13      13  NORBERT THE NORWEGIAN RIDGEBACK  Quirrell, how...       14     1
# 14      14  THE FORIBIDDEN FOREST  Things couldn't have be...       15     1
# 15      15  THROUGH THE TRAPDOOR  In years to come, Harry ...       16     1
# 16      16  THE MAN WITH TWO FACES  It was Quirrell.  \You...       17     1
# 17       0  THE WORST BIRTHDAY  Not for the first time, an...        1     2
# 18       1    DOBBY'S WARNING  arry managed not to shout o...        2     2
# 19       2  THE BURROW  Ron.l\ breathed Harry, creeping to...        3     2
# 20       3  AT FL0VRR 11 $ HAND BLOTTS  ife at the Burrow ...        4     2
# 21       4  THE WHOMPING  WILLOW  he end of the summer vac...        5     2
# 22       5  GILDEROY LOCKHART  he next day, however, Harry...        6     2
# 23       6  Harry looked bemusedly at the photograph Colin...        7     2
# 24       7    \What are you talking about, Harry? Perhaps ...        8     2
# 25       8  THE WRTITING ON THE WALL  What's going on here...        9     2
# 26       9    THE ROGUE BLUDGER  ince the disastrous episo...       10     2
# 27      10    THE D-KJEL]ING C-L-IJIB  Harry woke up on Su...       11     2
# 28      11    THE POLYJUICE POTION  hey stepped off the st...       12     2
# 29      12    Malfoy started taking pictures with an imagi...       13     2
# ..     ...                                                ...      ...   ...
# 170      7  Three o'clock on the following afternoon found...        8     7
# 171      8  Everything seemed fuzzy, slow. Harry and Hermi...        9     7
# 172      9  Harry woke early next morning, wrapped in a sl...       10     7
# 173     10  If Kreacher could escape a lake full of Inferi...       11     7
# 174     11  As August wore on, the square of unkempt grass...       12     7
# 175     12  Ah, Mafalda!\ said Umbridge, looking at Hermio...       13     7
# 176     13  Harry opened his eyes and was dazzled by gold ...       14     7
# 177     14  Early next morning, before the other two were ...       15     7
# 178     15  When Harry woke the following day it was sever...       16     7
# 179     16  Harry, stop.\\"What's wrong?\"They had only ju...       17     7
# 180     17  The sun was coming up: The pure, colorless vas...       18     7
# 181     18  It was snowing by the time Hermione took over ...       19     7
# 182     19  Harry had not expected Hermione's anger to aba...       20     7
# 183     20  Harry turned to look at Ron and Hermione. Neit...       21     7
# 184     21  Harry fell, panting, onto grass and scrambled ...       22     7
# 185     22  Harry looked around at the other two, now mere...       23     7
# 186     23  It was like sinking into an old nightmare; for...       24     7
# 187     24  Bill and Fleur's cottage stood alone on a clif...       25     7
# 188     25  Their plans were made, their preparations comp...       26     7
# 189     26  There was no means of steering; the dragon cou...       27     7
# 190     27  Harry's feet touched the road. He saw the achi...       28     7
# 191     28  Neville ¨C what the ¨C how ¨C?\But Neville had...       29     7
# 192     29  The moment her finger touched the Mark, Harry'...       30     7
# 193     30  The enchanted ceiling of the Great Hall was da...       31     7
# 194     31  The world had ended, so why had the battle not...       32     7
# 195     32  Harry remained kneeling at Snape's side, simpl...       33     7
# 196     33  Finally, the truth. Lying with his face presse...       34     7
# 197     34  He lay facedown, listening to the silence. He ...       35     7
# 198     35  He was flying facedown on the ground again. Th...       36     7
# 199     36  Autumn seemed to arrive suddenly that year. Th...       37     7
#
#                                          WordCountText  \
# 0    [the, boy, who, lived, mr, and, mrs, dursley, ...
# 1    [the, vanishing, glass, nearly, ten, years, ha...
# 2    [the, letters, from, no, one, the, escape, of,...
# 3    [the, keeper, of, the, keys, boom, they, knock...
# 4    [diagon, alley, harry, woke, early, the, next,...
# 5    [the, journey, from, platform, nine, and, thre...
# 6    [the, sorting, hat, the, door, swung, open, at...
# 7    [the, potions, master, there, look, where, nex...
# 8    [the, midnight, duel, harry, had, never, belie...
# 9    [halloween, malfoy, couldnt, believe, his, eye...
# 10   [quidditch, as, they, entered, november, the, ...
# 11   [the, mirror, of, erised, christmas, was, comi...
# 12   [nicolas, flamel, dumbledore, had, convinced, ...
# 13   [norbert, the, norwegian, ridgeback, quirrell,...
# 14   [the, foribidden, forest, things, couldnt, hav...
# 15   [through, the, trapdoor, in, years, to, come, ...
# 16   [the, man, with, two, faces, it, was, quirrell...
# 17   [the, worst, birthday, not, for, the, first, t...
# 18   [dobbys, warning, arry, managed, not, to, shou...
# 19   [the, burrow, ronl, breathed, harry, creeping,...
# 20   [at, fl0vrr, 11, hand, blotts, ife, at, the, b...
# 21   [the, whomping, willow, he, end, of, the, summ...
# 22   [gilderoy, lockhart, he, next, day, however, h...
# 23   [harry, looked, bemusedly, at, the, photograph...
# 24   [what, are, you, talking, about, harry, perhap...
# 25   [the, wrtiting, on, the, wall, whats, going, o...
# 26   [the, rogue, bludger, ince, the, disastrous, e...
# 27   [the, dkjeling, clijib, harry, woke, up, on, s...
# 28   [the, polyjuice, potion, hey, stepped, off, th...
# 29   [malfoy, started, taking, pictures, with, an, ...
# ..                                                 ...
# 170  [three, oclock, on, the, following, afternoon,...
# 171  [everything, seemed, fuzzy, slow, harry, and, ...
# 172  [harry, woke, early, next, morning, wrapped, i...
# 173  [if, kreacher, could, escape, a, lake, full, o...
# 174  [as, august, wore, on, the, square, of, unkemp...
# 175  [ah, mafalda, said, umbridge, looking, at, her...
# 176  [harry, opened, his, eyes, and, was, dazzled, ...
# 177  [early, next, morning, before, the, other, two...
# 178  [when, harry, woke, the, following, day, it, w...
# 179  [harry, stopwhats, wrongthey, had, only, just,...
# 180  [the, sun, was, coming, up, the, pure, colorle...
# 181  [it, was, snowing, by, the, time, hermione, to...
# 182  [harry, had, not, expected, hermiones, anger, ...
# 183  [harry, turned, to, look, at, ron, and, hermio...
# 184  [harry, fell, panting, onto, grass, and, scram...
# 185  [harry, looked, around, at, the, other, two, n...
# 186  [it, was, like, sinking, into, an, old, nightm...
# 187  [bill, and, fleurs, cottage, stood, alone, on,...
# 188  [their, plans, were, made, their, preparations...
# 189  [there, was, no, means, of, steering, the, dra...
# 190  [harrys, feet, touched, the, road, he, saw, th...
# 191  [neville, ¨c, what, the, ¨c, how, ¨cbut, nevil...
# 192  [the, moment, her, finger, touched, the, mark,...
# 193  [the, enchanted, ceiling, of, the, great, hall...
# 194  [the, world, had, ended, so, why, had, the, ba...
# 195  [harry, remained, kneeling, at, snapes, side, ...
# 196  [finally, the, truth, lying, with, his, face, ...
# 197  [he, lay, facedown, listening, to, the, silenc...
# 198  [he, was, flying, facedown, on, the, ground, a...
# 199  [autumn, seemed, to, arrive, suddenly, that, y...
#
#                                          WordCloudText  WordCount
# 0    [boy, lived, mr, mrs, dursley, number, four, p...       4591
# 1    [vanishing, glass, nearly, ten, years, passed,...       3445
# 2    [letters, one, escape, brazilian, boa, constri...       3842
# 3    [keeper, keys, boom, knocked, dudley, jerked, ...       3690
# 4    [diagon, alley, harry, woke, early, next, morn...       6570
# 5    [journey, platform, nine, threequarters, harry...       6283
# 6    [sorting, hat, door, swung, open, tall, blackh...       4469
# 7    [potions, master, look, next, tall, kid, red, ...       3064
# 8    [midnight, duel, harry, never, believed, would...       4903
# 9    [halloween, malfoy, believe, eyes, saw, harry,...       4282
# 10   [quidditch, entered, november, weather, turned...       3331
# 11   [mirror, erised, christmas, coming, one, morni...       5484
# 12   [nicolas, flamel, dumbledore, convinced, harry...       3182
# 13   [norbert, norwegian, ridgeback, quirrell, howe...       3466
# 14   [foribidden, forest, things, worse, filch, too...       5087
# 15   [trapdoor, years, come, harry, would, never, q...       6421
# 16   [man, two, faces, quirrell, gasped, harry, qui...       5465
# 17   [worst, birthday, first, time, argument, broke...       2581
# 18   [dobbys, warning, arry, managed, shout, close,...       2858
# 19   [burrow, ronl, breathed, harry, creeping, wind...       4486
# 20   [fl0vrr, 11, hand, blotts, ife, burrow, differ...       5784
# 21   [whomping, willow, end, summer, vacation, came...       5182
# 22   [gilderoy, lockhart, next, day, however, harry...       4992
# 23   [harry, looked, bemusedly, photograph, colin, ...       3892
# 24   [talking, harry, perhaps, getting, litde, drow...       4648
# 25   [wrtiting, wall, whats, going, whats, going, a...       5166
# 26   [rogue, bludger, ince, disastrous, episode, pi...       5292
# 27   [dkjeling, clijib, harry, woke, sunday, mornin...       5980
# 28   [polyjuice, potion, hey, stepped, stone, stair...       4489
# 29   [malfoy, started, taking, pictures, imaginary,...       3221
# ..                                                 ...        ...
# 170  [three, oclock, following, afternoon, found, h...       6033
# 171  [everything, seemed, fuzzy, slow, harry, hermi...       4010
# 172  [harry, woke, early, next, morning, wrapped, s...       6435
# 173  [kreacher, could, escape, lake, full, inferi, ...       5391
# 174  [august, wore, square, unkempt, grass, middle,...       5941
# 175  [ah, mafalda, said, umbridge, looking, hermion...       5698
# 176  [harry, opened, eyes, dazzled, gold, green, id...       4114
# 177  [early, next, morning, two, awake, harry, left...       6788
# 178  [harry, woke, following, day, several, seconds...       5094
# 179  [harry, stopwhats, wrongthey, reached, grave, ...       5230
# 180  [sun, coming, pure, colorless, vastness, sky, ...       3402
# 181  [snowing, time, hermione, took, watch, midnigh...       6527
# 182  [harry, expected, hermiones, anger, abate, nig...       4331
# 183  [harry, turned, look, ron, hermione, neither, ...       4655
# 184  [harry, fell, panting, onto, grass, scrambled,...       5632
# 185  [harry, looked, around, two, mere, outlines, d...       7546
# 186  [like, sinking, old, nightmare, instant, harry...       6501
# 187  [bill, fleurs, cottage, stood, alone, cliff, o...       4209
# 188  [plans, made, preparations, complete, smallest...       6668
# 189  [means, steering, dragon, could, see, going, h...       2577
# 190  [harrys, feet, touched, road, saw, achingly, f...       4353
# 191  [neville, ¨c, ¨c, ¨cbut, neville, spotted, ron...       4388
# 192  [moment, finger, touched, mark, harrys, scar, ...       4717
# 193  [enchanted, ceiling, great, hall, dark, scatte...       7683
# 194  [world, ended, battle, ceased, castle, fallen,...       5373
# 195  [harry, remained, kneeling, snapes, side, simp...       7930
# 196  [finally, truth, lying, face, pressed, dusty, ...       3762
# 197  [lay, facedown, listening, silence, perfectly,...       4846
# 198  [flying, facedown, ground, smell, forest, fill...       6943
# 199  [autumn, seemed, arrive, suddenly, year, morni...       1552
#
# [200 rows x 7 columns]

# %%
df.head(5) #Look at top 5 rows - Make sure everything looks appropriate
# Out:
#                                                 Text  Chapter  Book  \
# 0  THE BOY WHO LIVED  Mr. and Mrs. Dursley, of nu...        1     1
# 1  THE VANISHING GLASS  Nearly ten years had pass...        2     1
# 2  THE LETTERS FROM NO ONE  The escape of the Bra...        3     1
# 3  THE KEEPER OF THE KEYS  BOOM. They knocked aga...        4     1
# 4  DIAGON ALLEY  Harry woke early the next mornin...        5     1
#
#                                        WordCountText  \
# 0  [the, boy, who, lived, mr, and, mrs, dursley, ...
# 1  [the, vanishing, glass, nearly, ten, years, ha...
# 2  [the, letters, from, no, one, the, escape, of,...
# 3  [the, keeper, of, the, keys, boom, they, knock...
# 4  [diagon, alley, harry, woke, early, the, next,...
#
#                                        WordCloudText  WordCount
# 0  [boy, lived, mr, mrs, dursley, number, four, p...       4591
# 1  [vanishing, glass, nearly, ten, years, passed,...       3445
# 2  [letters, one, escape, brazilian, boa, constri...       3842
# 3  [keeper, keys, boom, knocked, dudley, jerked, ...       3690
# 4  [diagon, alley, harry, woke, early, next, morn...       6570

# %% [markdown]
# ### Word Count Graphs

# %%
#Import packages
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#Set defaults for graph formats
plt.rcParams['figure.figsize']=(15,10) #Sets default for the size of the graph
matplotlib.rcParams['axes.titlesize']=24 #Sets default for the size of the title
matplotlib.rcParams['axes.labelsize']=20 #Sets default for the size of the x/y axis labels

# %% [markdown]
# Number of Words in Each Harry Potter Book

# %%
BookTitles=["Philosopher's Stone", "Chamber of Secrets", "Prisoner of Azkaban", "Goblet of Fire",
           "Order of the Phoenix", "Half Blood Prince", "Deathly Hallows"]

x = df.groupby(['Book'])['WordCount'].sum().reset_index()['Book']
y = df.groupby(['Book'])['WordCount'].sum().reset_index()['WordCount']
x_pos = np.arange(len(x))
plt.style.use('ggplot')
barchart=plt.bar(x_pos, y, color=['#DC8458', '#950702', '#8E067D', '#2E8C44', '#395196', '#60A619','#ECA10A'])
plt.xlabel("Book")
plt.ylabel("Word Count")
plt.title("Total Number of Words in Each Harry Potter Book")
plt.xticks(x_pos, BookTitles)

# Add counts above the two bar graphs
for bar in barchart:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')


#plt.savefig('C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Output/HPtotalwords.png')

# %% [markdown]
# Average Number of Words Per Chapter of Harry Potter

# %%
BookTitles=["Philosopher's Stone", "Chamber of Secrets", "Prisoner of Azkaban", "Goblet of Fire",
           "Order of the Phoenix", "Half Blood Prince", "Deathly Hallows"]

x = df.groupby(['Book'])['WordCount'].mean().reset_index()['Book']
y = df.groupby(['Book'])['WordCount'].mean().reset_index()['WordCount']
x_pos = np.arange(len(x))
plt.style.use('ggplot')
barchart=plt.bar(x_pos, y, color=['#DC8458', '#950702', '#8E067D', '#2E8C44', '#395196', '#60A619','#ECA10A'])
plt.xlabel("Book")
plt.ylabel("Word Count")
plt.title("Average Number of Words Per Chapter of Each Harry Potter Book")
plt.xticks(x_pos, BookTitles)

# Add counts above the two bar graphs
for bar in barchart:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

#plt.savefig('C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Output/HPavgwords.png')

# %% [markdown]
# Shortest Chapter of Each Harry Potter Book

# %%
BookTitles=["Philosopher's Stone", "Chamber of Secrets", "Prisoner of Azkaban", "Goblet of Fire",
           "Order of the Phoenix", "Half Blood Prince", "Deathly Hallows"]

x = df.groupby(['Book'])['WordCount'].min().reset_index()['Book']
y = df.groupby(['Book'])['WordCount'].min().reset_index()['WordCount']
x_pos = np.arange(len(x))
plt.style.use('ggplot')
barchart=plt.bar(x_pos, y, color=['#DC8458', '#950702', '#8E067D', '#2E8C44', '#395196', '#60A619','#ECA10A'])
plt.xlabel("Book")
plt.ylabel("Word Count")
plt.title("Shortest Chapter of Each Harry Potter Book")
plt.xticks(x_pos, BookTitles)

# Add counts above the two bar graphs
for bar in barchart:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')

#plt.savefig('C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Output/HPshortchaps.png')

# %% [markdown]
# Longest Chapter of Each Harry Potter Book

# %%
BookTitles=["Philosopher's Stone", "Chamber of Secrets", "Prisoner of Azkaban", "Goblet of Fire",
           "Order of the Phoenix", "Half Blood Prince", "Deathly Hallows"]

x = df.groupby(['Book'])['WordCount'].max().reset_index()['Book']
y = df.groupby(['Book'])['WordCount'].max().reset_index()['WordCount']
x_pos = np.arange(len(x))
plt.style.use('ggplot')
barchart=plt.bar(x_pos, y, color=['#DC8458', '#950702', '#8E067D', '#2E8C44', '#395196', '#60A619','#ECA10A'])
plt.xlabel("Book")
plt.ylabel("Word Count")
plt.title("Longest Chapter of Each Harry Potter Book")
plt.xticks(x_pos, BookTitles)

# Add counts above the two bar graphs
for bar in barchart:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom')
    
#plt.savefig('C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Output/HPlongchaps.png')

# %% [markdown]
# Which chapter was the shortest?

# %%
one = df.groupby(['Book'])['WordCount'].min().reset_index()['Book']
two = df.groupby(['Book'])['WordCount'].min().reset_index()['WordCount']

#del MinChaps

MinChaps=pd.DataFrame()

for (a, b) in zip(one, two): 
     MinChaps = pd.concat([MinChaps, df[(df.WordCount == b) & (df.Book == a)]])

MinChaps
# Out:
#                                                  Text  Chapter  Book  \
# 7   THE POTIONS MASTER  There, look.\  \"Where?\" ...        8     1
# 13  still, heart-shaped confetti was falling from ...       14     2
# 19    THE DEMENTOR'S KISS  Harry had never been pa...       20     3
# 31     Harry felt his feet slam into the ground; h...       32     4
# 35  The Only OneHe Ever Feared'He hasn't gone!' Ha...       36     5
# 27   Harry felt as though he too were hurtling thr...       28     6
# 36  Autumn seemed to arrive suddenly that year. Th...       37     7
#
#                                         WordCountText  \
# 7   [the, potions, master, there, look, where, nex...
# 13  [still, heartshaped, confetti, was, falling, f...
# 19  [the, dementors, kiss, harry, had, never, been...
# 31  [harry, felt, his, feet, slam, into, the, grou...
# 35  [the, only, onehe, ever, fearedhe, hasnt, gone...
# 27  [harry, felt, as, though, he, too, were, hurtl...
# 36  [autumn, seemed, to, arrive, suddenly, that, y...
#
#                                         WordCloudText  WordCount
# 7   [potions, master, look, next, tall, kid, red, ...       3064
# 13  [still, heartshaped, confetti, falling, pale, ...       2378
# 19  [dementors, kiss, harry, never, part, stranger...       1937
# 31  [harry, felt, feet, slam, ground, injured, leg...       2002
# 35  [onehe, ever, fearedhe, gone, harry, yelled, b...       3823
# 27  [harry, felt, though, hurtling, space, happene...       3549
# 36  [autumn, seemed, arrive, suddenly, year, morni...       1552

# %% [markdown]
# Which chapter was the longest?

# %%
one = df.groupby(['Book'])['WordCount'].max().reset_index()['Book']
two = df.groupby(['Book'])['WordCount'].max().reset_index()['WordCount']

#del MaxChaps

MaxChaps=pd.DataFrame()

for (a, b) in zip(one, two): 
     MaxChaps = pd.concat([MaxChaps, df[(df.WordCount == b) & (df.Book == a)]])
        
MaxChaps
# Out:
#                                                  Text  Chapter  Book  \
# 4   DIAGON ALLEY  Harry woke early the next mornin...        5     1
# 18    \What d'you mean, I won't be -?\"  \"I've wa...       19     2
# 20    HERMIONE'S SECRET  Shocking business... shoc...       21     3
# 22     Despite the very heavy load of homework tha...       23     4
# 12  Dentention with DeloresDinner in the Great Hal...       13     5
# 17   The next day Harry confided in both Ron and H...       18     6
# 32  Harry remained kneeling at Snape's side, simpl...       33     7
#
#                                         WordCountText  \
# 4   [diagon, alley, harry, woke, early, the, next,...
# 18  [what, dyou, mean, i, wont, be, ive, waited, a...
# 20  [hermiones, secret, shocking, business, shocki...
# 22  [despite, the, very, heavy, load, of, homework...
# 12  [dentention, with, deloresdinner, in, the, gre...
# 17  [the, next, day, harry, confided, in, both, ro...
# 32  [harry, remained, kneeling, at, snapes, side, ...
#
#                                         WordCloudText  WordCount
# 4   [diagon, alley, harry, woke, early, next, morn...       6570
# 18  [dyou, mean, ive, waited, long, time, harry, p...       8528
# 20  [hermiones, secret, shocking, business, shocki...       7237
# 22  [despite, heavy, load, homework, fourth, years...       8177
# 12  [dentention, deloresdinner, great, hall, night...       8928
# 17  [next, day, harry, confided, ron, hermione, ta...       7045
# 32  [harry, remained, kneeling, snapes, side, simp...       7930

# %% [markdown]
# ### Save copy of df - For Word Cloud, Sentiment Analysis

# %%
df.to_excel("C://Users/cluel/Documents/GitHub/Harry-Potter-Text-Mining/Output/df.xlsx", index=False)
